# %% [markdown]
# <a href="https://colab.research.google.com/github/khushbu1998/covid19/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import plotly.graph_objects as go

# %%
url1 ='https://raw.githubusercontent.com/khushbu1998/covid19/master/Italy_17thmay.csv'
url2='https://raw.githubusercontent.com/khushbu1998/covid19/master/Brazil_17thmay.csv'
url3='https://raw.githubusercontent.com/khushbu1998/covid19/master/India_17thmay.csv'
url4='https://raw.githubusercontent.com/khushbu1998/covid19/master/Russia_17thmay.csv'

# %%
Italy = pd.read_csv(url1)
Brazil = pd.read_csv(url2)
India= pd.read_csv(url3)
Russia= pd.read_csv(url4)

# %%
Italy['Date '] = pd.to_datetime(Italy['Date '])
Italy= Italy.sort_values('Date ')
Brazil['Date '] = pd.to_datetime(Brazil['Date '])
Brazil= Brazil.sort_values('Date ')
India['Date '] = pd.to_datetime(India['Date '])
India= India.sort_values('Date ')
Russia['Date '] = pd.to_datetime(Russia['Date '])
Russia= Russia.sort_values('Date ')

# %%
Italy
# Out:
#          Date   Cases  Death  Cummulative cases   Cummulative death
# 137 2020-01-01      0      0                   0                   0
# 136 2020-01-02      0      0                   0                   0
# 135 2020-01-03      0      0                   0                   0
# 134 2020-01-04      0      0                   0                   0
# 133 2020-01-05      0      0                   0                   0
# ..         ...    ...    ...                 ...                 ...
# 4   2020-05-13   1402    172              221216               30911
# 3   2020-05-14    888    195              222104               31106
# 2   2020-05-15    992    262              223096               31368
# 1   2020-05-16    789    242              223885               31610
# 0   2020-05-17    875    153              224760               31763
#
# [138 rows x 5 columns]

# %%
from plotly.subplots import make_subplots

# %%
fig=make_subplots(rows=2,cols=2,specs=[[{},{}],[{},{}]], subplot_titles=('Italy','Brazil','India','Russia'))

# %%
fig.add_trace(go.Bar(x=Italy['Date '],y=Italy['Cummulative cases '],marker=dict(color=Italy['Cummulative cases '],coloraxis="coloraxis",)),1,1)
fig.add_trace(go.Bar(x=Brazil['Date '],y=Brazil['Cummulative cases '],marker=dict(color=Brazil['Cummulative cases '],coloraxis="coloraxis",)),1,2)
fig.add_trace(go.Bar(x=India['Date '],y=India['Cummulative cases '],marker=dict(color=India['Cummulative cases '],coloraxis="coloraxis",)),2,1)
fig.add_trace(go.Bar(x=Russia['Date '],y=Russia['Cummulative cases '],marker=dict(color=Russia['Cummulative cases '],coloraxis="coloraxis",)),2,2)
fig.update_layout(coloraxis=dict(colorscale='Bluered_r'),showlegend=False,title_text='Total Cases(Cummulative)')
fig.update_layout(plot_bgcolor='rgb(230,230,230)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e3520764-89fb-4ef5-952a-5d9cae2ebce5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e3520764-89fb-4ef5-952a-5d9cae2ebce5")) {
#                     Plotly.newPlot(
#                         'e3520764-89fb-4ef5-952a-5d9cae2ebce5',
# ...

# %%
fig1=make_subplots(rows=2,cols=2,specs=[[{},{}],[{},{}]], subplot_titles=('Italy','Brazil','India','Russia'))
fig1.add_trace(go.Bar(x=Italy['Date '],y=Italy['Cummulative death '],marker=dict(color=Italy['Cummulative death '],coloraxis="coloraxis",)),1,1)
fig1.add_trace(go.Bar(x=Brazil['Date '],y=Brazil['Cummulative death '],marker=dict(color=Brazil['Cummulative death '],coloraxis="coloraxis",)),1,2)
fig1.add_trace(go.Bar(x=India['Date '],y=India['Cummulative death '],marker=dict(color=India['Cummulative death '],coloraxis="coloraxis",)),2,1)
fig1.add_trace(go.Bar(x=Russia['Date '],y=Russia['Cummulative death '],marker=dict(color=Russia['Cummulative death '],coloraxis="coloraxis",)),2,2)
fig1.update_layout(coloraxis=dict(colorscale='Bluered_r'),showlegend=False,title_text='Total Deaths(Cummulative)')
fig1.update_layout(plot_bgcolor='rgb(230,230,230)')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0fba39a3-da03-4d23-9177-f69a5521a417" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0fba39a3-da03-4d23-9177-f69a5521a417")) {
#                     Plotly.newPlot(
#                         '0fba39a3-da03-4d23-9177-f69a5521a417',
# ...
